# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('Dados-Pesquisa.csv')
# Out:
# C:\Users\Aluno\AppData\Local\Temp\ipykernel_2640\539505621.py:1: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('Dados-Pesquisa.csv')

# %%
dados.head(1-2)
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15614  47.0               0.0             NaN                   NaN
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                    NaN                NaN          NaN                 NaN
# 1                    NaN                NaN          NaN                 NaN
# 2                    NaN                NaN          NaN                 NaN
# 3                    NaN                NaN          NaN                 NaN
# 4                    NaN                NaN          NaN                 NaN
# ...                  ...                ...          ...                 ...
# 15614                NaN                NaN          NaN                 NaN
# 15615                NaN                NaN          NaN                 NaN
# 15616                NaN                NaN          NaN                 NaN
# 15617                NaN                NaN          NaN                 NaN
# 15618                NaN                NaN          NaN                 NaN
#
#        BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                    NaN             NaN  ...               NaN
# 1                    NaN             NaN  ...               NaN
# 2                    NaN             NaN  ...               NaN
# 3                    NaN             NaN  ...               NaN
# 4                    NaN             NaN  ...               NaN
# ...                  ...             ...  ...               ...
# 15614                NaN             NaN  ...               NaN
# 15615                NaN             NaN  ...               NaN
# 15616                NaN             NaN  ...               NaN
# 15617                NaN             NaN  ...               NaN
# 15618                NaN             NaN  ...               NaN
#
#        ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  \
# 0                        NaN                NaN              NaN
# 1                        NaN                NaN              NaN
# 2                        NaN                NaN              NaN
# 3                        NaN                NaN              NaN
# 4                        NaN                NaN              NaN
# ...                      ...                ...              ...
# 15614                    NaN                NaN              NaN
# 15615                    NaN                NaN              NaN
# 15616                    NaN                1.0              NaN
# 15617                    NaN                NaN              NaN
# 15618                    NaN                NaN              NaN
#
#        ResourceUdemy  ResourceW3Schools  ResourceYouTube  \
# 0                NaN                NaN              NaN
# 1                1.0                NaN              NaN
# 2                NaN                NaN              NaN
# 3                NaN                NaN              NaN
# 4                NaN                NaN              NaN
# ...              ...                ...              ...
# 15614            NaN                NaN              NaN
# 15615            1.0                NaN              NaN
# 15616            NaN                NaN              NaN
# 15617            NaN                NaN              NaN
# 15618            1.0                NaN              NaN
#
#                                    SchoolDegree              SchoolMajor  \
# 0                some college credit, no degree                      NaN
# 1                some college credit, no degree                      NaN
# 2       high school diploma or equivalent (GED)                      NaN
# 3                             bachelor's degree  Cinematography And Film
# 4                some college credit, no degree                      NaN
# ...                                         ...                      ...
# 15614  trade, technical, or vocational training                      NaN
# 15615                         bachelor's degree                Chemistry
# 15616                         bachelor's degree   Electrical Engineering
# 15617                         bachelor's degree                Chemistry
# 15618        master's degree (non-professional)                     Math
#
#        StudentDebtOwe
# 0             20000.0
# 1                 NaN
# 2                 NaN
# 3              7000.0
# 4                 NaN
# ...               ...
# 15614             NaN
# 15615             NaN
# 15616             NaN
# 15617             NaN
# 15618             NaN
#
# [15619 rows x 113 columns]

# %%
dados.columns.to_list()
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
#  'HasStudentDebt',
#  'HomeMortgageOwe',
#  'HoursLearning',
#  'ID.x',
#  'ID.y',
#  'Income',
#  'IsEthnicMinority',
#  'IsReceiveDiabilitiesBenefits',
#  'IsSoftwareDev',
#  'IsUnderEmployed',
#  'JobApplyWhen',
#  'JobPref',
#  'JobRelocateYesNo',
#  'JobRoleInterest',
#  'JobRoleInterestOther',
#  'JobWherePref',
#  'LanguageAtHome',
#  'MaritalStatus',
#  'MoneyForLearning',
#  'MonthsProgramming',
#  'NetworkID',
#  'Part1EndTime',
#  'Part1StartTime',
#  'Part2EndTime',
#  'Part2StartTime',
#  'PodcastChangeLog',
#  'PodcastCodeNewbie',
#  'PodcastCodingBlocks',
#  'PodcastDeveloperTea',
#  'PodcastDotNetRocks',
#  'PodcastHanselminutes',
#  'PodcastJSJabber',
#  'PodcastJsAir',
#  'PodcastNone',
#  'PodcastOther',
#  'PodcastProgrammingThrowDown',
#  'PodcastRubyRogues',
#  'PodcastSEDaily',
#  'PodcastShopTalk',
#  'PodcastTalkPython',
#  'PodcastWebAhead',
#  'ResourceBlogs',
#  'ResourceBooks',
#  'ResourceCodeWars',
#  'ResourceCodecademy',
#  'ResourceCoursera',
#  'ResourceDevTips',
#  'ResourceEdX',
#  'ResourceEggHead',
#  'ResourceFCC',
#  'ResourceGoogle',
#  'ResourceHackerRank',
#  'ResourceKhanAcademy',
#  'ResourceLynda',
#  'ResourceMDN',
#  'ResourceOdinProj',
#  'ResourceOther',
#  'ResourcePluralSight',
#  'ResourceReddit',
#  'ResourceSkillCrush',
#  'ResourceSoloLearn',
#  'ResourceStackOverflow',
#  'ResourceTreehouse',
#  'ResourceUdacity',
#  'ResourceUdemy',
#  'ResourceW3Schools',
#  'ResourceYouTube',
#  'SchoolDegree',
#  'SchoolMajor',
#  'StudentDebtOwe']

# %%
df2 = dados.copy()

# %%
dados.isna().sum()
# Out:
# Age                      2007
# AttendedBootcamp          240
# BootcampFinish          14687
# BootcampFullJobAfter    14985
# BootcampLoanYesNo       14686
#                         ...
# ResourceW3Schools       15499
# ResourceYouTube         15499
# SchoolDegree             1941
# SchoolMajor              7170
# StudentDebtOwe          12106
# Length: 113, dtype: int64

# %%
dados.isna().sum().sum()
# Out:
# 1183960

# %%
dados.dropna(subset= ['Age'], inplace=True)

# %%
dados.isna().sum()
# Out:
# Age                         0
# AttendedBootcamp          112
# BootcampFinish          12809
# BootcampFullJobAfter    13068
# BootcampLoanYesNo       12805
#                         ...
# ResourceW3Schools       13508
# ResourceYouTube         13506
# SchoolDegree              113
# SchoolMajor              5265
# StudentDebtOwe          10121
# Length: 113, dtype: int64

# %%
dados.dtypes.value_counts()
# Out:
# float64    85
# object     28
# Name: count, dtype: int64

# %%
dados = dados[['Age', 'Gender', 'JobPref', 'JobRoleInterest', 'JobRelocateYesNo', 'HoursLearning', 'MoneyForLearning' ]]

# %%
dados
# Out:
#         Age  Gender                          JobPref  \
# 0      28.0    male                       freelance
# 1      22.0    male               work for a startup
# 2      19.0    male          start your own business
# 3      26.0  female               work for a startup
# 4      20.0  female  work for a medium-sized company
# ...     ...     ...                              ...
# 15615  39.0    male          start your own business
# 15616  27.0    male               work for a startup
# 15617  37.0    male                       freelance
# 15618  26.0    male                              NaN
# 15619  22.0  female                       freelance
#
#                  JobRoleInterest  JobRelocateYesNo  HoursLearning  \
# 0                            NaN               NaN           30.0
# 1        Front-End Web Developer               1.0           30.0
# 2                            NaN               NaN           20.0
# 3        Front-End Web Developer               NaN           20.0
# 4       Full-Stack Web Developer               1.0           25.0
# ...                          ...               ...            ...
# 15615                        NaN               NaN           40.0
# 15616    Front-End Web Developer               1.0           15.0
# 15617                        NaN               NaN           14.0
# 15618                        NaN               NaN           10.0
# 15619                        NaN               NaN            2.0
#
#        MoneyForLearning
# 0                   0.0
# 1                  20.0
# 2                  50.0
# 3                 100.0
# 4                1300.0
# ...                 ...
# 15615               0.0
# 15616             100.0
# 15617               0.0
# 15618              30.0
# 15619               0.0
#
# [13613 rows x 7 columns]

# %%
dados = dados.drop_duplicates()

# %%
dados.shape
# Out:
# (11348, 7)

# %%
dados.describe()
# Out:
#                 Age  JobRelocateYesNo  HoursLearning  MoneyForLearning
# count  11348.000000       4559.000000   10941.000000      10770.000000
# mean      29.748149          0.729327      16.042592       1280.816527
# std        9.390044          0.444356      14.836902       5184.728603
# min       10.000000          0.000000       0.000000          0.000000
# 25%       23.000000          0.000000       5.000000          0.000000
# 50%       28.000000          1.000000      10.000000         60.000000
# 75%       34.000000          1.000000      20.000000        499.750000
# max       86.000000          1.000000     100.000000     180000.000000

# %%
dados.describe(include='O')
# Out:
#        Gender                          JobPref           JobRoleInterest
# count   11308                             8741                      5434
# unique      5                                5                         9
# top      male  work for a medium-sized company  Full-Stack Web Developer
# freq     8554                             2772                      2132

# %%
dados.loc[dados['Age'] > 30]
# Out:
#         Age  Gender                  JobPref JobRoleInterest  \
# 5      34.0    male  start your own business             NaN
# 7      35.0    male               freelance              NaN
# 8      33.0    male                      NaN             NaN
# 9      33.0    male  start your own business             NaN
# 10     57.0    male               freelance              NaN
# ...     ...     ...                      ...             ...
# 15609  33.0    male                      NaN             NaN
# 15611  37.0    male  start your own business             NaN
# 15612  45.0  female  start your own business             NaN
# 15614  47.0    male               freelance              NaN
# 15615  39.0    male  start your own business             NaN
#
#        JobRelocateYesNo  HoursLearning  MoneyForLearning
# 5                   NaN            5.0               0.0
# 7                   NaN            NaN               0.0
# 8                   NaN            5.0            3000.0
# 9                   NaN           20.0              30.0
# 10                  NaN            8.0             400.0
# ...                 ...            ...               ...
# 15609               NaN           16.0               NaN
# 15611               NaN           40.0             200.0
# 15612               NaN            2.0             300.0
# 15614               NaN            3.0               0.0
# 15615               NaN           40.0               0.0
#
# [4278 rows x 7 columns]

# %%
idade = dados.Age
idade
# Out:
# 0        28.0
# 1        22.0
# 2        19.0
# 3        26.0
# 4        20.0
#          ...
# 15614    47.0
# 15615    39.0
# 15616    27.0
# 15618    26.0
# 15619    22.0
# Name: Age, Length: 11348, dtype: float64

# %%
plt.hist(idade, label='Idade', color ='lightseagreen')
plt.title('Distribução por idade')
plt.xlabel('Idade')
plt.ylabel('Quantidade')
plt.legend()
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dados.Gender.value_counts()
# Out:
# Gender
# male           8554
# female         2617
# genderqueer      65
# agender          36
# trans            36
# Name: count, dtype: int64

# %%
dados.Gender.value_counts().sum()
# Out:
# 11308

# %%
tipo_de_genero = pd.DataFrame(dados.Gender.value_counts())

# %%
tipo_de_genero.head()
# Out:
#              count
# Gender
# male          8554
# female        2617
# genderqueer     65
# agender         36
# trans           36

# %%
feminino = tipo_de_genero.iloc[1]
feminino
# Out:
# count    2617
# Name: female, dtype: int64

# %%
total_genero = dados.Gender.value_counts().sum()

# %%
fem = (feminino/total_genero * 100)
fem
# Out:
# count    23.142908
# Name: female, dtype: float64

# %%
type(total_genero)
# Out:
# numpy.int64

# %%
genero = dados.Gender.value_counts()

# %%
plt.pie(genero)
# Out:
# ([<matplotlib.patches.Wedge at 0x137c41b7b00>,
#   <matplotlib.patches.Wedge at 0x137c41b61e0>,
#   <matplotlib.patches.Wedge at 0x137c41b7110>,
#   <matplotlib.patches.Wedge at 0x137c41b6de0>,
#   <matplotlib.patches.Wedge at 0x137c41b7a70>],
#  [Text(-0.7934312319269614, 0.7618837707963496, ''),
#   Text(0.7638652053980911, -0.7915238139071573, ''),
#   Text(1.0981462011972063, -0.06383510629853473, ''),
#   Text(1.0995048826879033, -0.03300019614275453, ''),
#   Text(1.0999449826956327, -0.011001592734898796, '')])

# %%
genero = dados.Gender.value_counts()
plt.pie(genero)
plt.legend(dados.Gender.value_counts().index)
plt.show()
